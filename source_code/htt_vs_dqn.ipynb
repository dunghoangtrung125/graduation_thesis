# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import ScalarFormatter

df_dqn = pd.read_csv('csv/ddqn.csv')
df_q_learning = pd.read_csv('csv/q_learning.csv')

# plt.figure(figsize=(10, 5))  # Set the figure size
plt.ticklabel_format(axis='x', style='sci', scilimits=(0, 6))
plt.xlim(0, 10 * 10**5)
plt.plot(df_dqn['Iteration'], df_dqn['Avg Throughput'], label='DQN')
plt.plot(df_q_learning['Iteration'], df_q_learning['Avg Throughput'], label='Q_learning', linestyle='dashdot')
plt.ylabel('Avg reward', fontsize = 13)
plt.xlabel('Iterations', fontsize = 13)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid(True)
plt.tight_layout()
plt.legend()
formatter = ScalarFormatter(useMathText=True)
plt.gca().xaxis.set_major_formatter(formatter)
plt.show()

# %%
from parameters import *
from simulation.harvest_then_transmit import HarvestThenTransmitt

for i in range(10):
    htt = HarvestThenTransmitt(d_t=i+1)
    htt.run()
# Out:
# ---------------------------------------------------
# Result after running simulation in 5000 time units
# Number packages sent successfully = 558
# Avg throughput (packages/time unit) = 0.1116
# Avg loss (packages/time unit) = 2.88
# PDR = 3.7279529663281665%
# ---------------------------------------------------
# csv/htt_throughput.csv created with 2 columns.
# csv/htt_loss.csv created with 2 columns.
# csv/htt_pdr.csv created with 2 columns.
# ---------------------------------------------------
# Result after running simulation in 5000 time units
# Number packages sent successfully = 994
# Avg throughput (packages/time unit) = 0.1988
# Avg loss (packages/time unit) = 2.8134
# PDR = 6.595448211797492%
# ---------------------------------------------------
# csv/htt_throughput.csv already exists.
# csv/htt_loss.csv already exists.
# csv/htt_pdr.csv already exists.
# ---------------------------------------------------
# Result after running simulation in 5000 time units
# ...

# %%
from simulation.ddqn_simulation import DDQNSimulate

for i in range(10):
    ddqn = DDQNSimulate(d_t=i+1)
    ddqn.run()
# Out:
# /opt/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: dqn is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# 2024-11-15 14:49:27.596654: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-15 14:49:27.596747: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_htt_throughput = pd.read_csv('csv/htt_throughput.csv')
df_dqn_throughput = pd.read_csv('csv/ddqn_throughput.csv')

plt.plot(df_htt_throughput['d_t'], df_htt_throughput['throughput'], marker='o', label='HTT')
plt.plot(df_dqn_throughput['d_t'], df_dqn_throughput['throughput'], marker='x', label='DQN')
plt.xlabel('dt')
plt.ylabel('Avg throughput (packages/time unit)')
plt.title('HTT vs Deep Q-Learning Avarage Throughput')
plt.tight_layout()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_htt_loss = pd.read_csv('csv/htt_loss.csv')
df_ddqn_loss = pd.read_csv('csv/ddqn_loss.csv')

plt.plot(df_htt_loss['d_t'], df_htt_loss['package_loss'], marker='o', label='HTT')
plt.plot(df_ddqn_loss['d_t'], df_ddqn_loss['package_loss'], marker='x', label='DQN')
plt.xlabel('dt')
plt.ylabel('Avg loss (packages/time unit)')
plt.title('HTT vs Deep Q-Learning Packages Loss')
plt.tight_layout()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_htt_loss = pd.read_csv('csv/htt_pdr.csv')
df_ddqn_loss = pd.read_csv('csv/ddqn_pdr.csv')

plt.plot(df_htt_loss['d_t'], df_htt_loss['pdr'], marker='o', label='HTT')
plt.plot(df_ddqn_loss['d_t'], df_ddqn_loss['pdr'], marker='x', label='DQN')
plt.xlabel('dt')
plt.ylabel('PDR (%)')
plt.title('HTT vs Deep Q-Learning PDR')
plt.tight_layout()
plt.legend()
plt.show()
