# %%
from deep_q_learning_agent import deep_q_learning_agent

deep_q_model = deep_q_learning_agent(dueling=True)
deep_q_model.learning()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Iteration 1000 reward: 0.611
# Iteration 2000 reward: 0.643
# Iteration 3000 reward: 0.7033333333333334
# Iteration 4000 reward: 0.74175
# Iteration 5000 reward: 0.7748
# Iteration 6000 reward: 0.806
# Iteration 7000 reward: 0.8382857142857143
# Iteration 8000 reward: 0.866375
# Iteration 9000 reward: 0.8941111111111111
# Iteration 10000 reward: 0.9258
# Iteration 11000 reward: 0.9499090909090909
# Iteration 12000 reward: 0.97075
# Iteration 13000 reward: 0.9921538461538462
# Iteration 14000 reward: 1.0127142857142857
# Iteration 15000 reward: 1.0304
# Iteration 16000 reward: 1.046625
# Iteration 17000 reward: 1.062470588235294
# Iteration 18000 reward: 1.077388888888889
# Iteration 19000 reward: 1.0904736842105263
# Iteration 20000 reward: 1.10465
# ...

# %%
from q_learning_agent import QLearningAgent
q_learning_agent = QLearningAgent()
q_learning_agent.learning()
# Out:
# Iteration 1000 reward: 1.411
# Iteration 2000 reward: 1.438
# Iteration 3000 reward: 1.4446666666666668
# Iteration 4000 reward: 1.43325
# Iteration 5000 reward: 1.4262
# Iteration 6000 reward: 1.4256666666666666
# Iteration 7000 reward: 1.425
# Iteration 8000 reward: 1.431625
# Iteration 9000 reward: 1.4336666666666666
# Iteration 10000 reward: 1.4321
# Iteration 11000 reward: 1.434
# Iteration 12000 reward: 1.4314166666666666
# Iteration 13000 reward: 1.43
# Iteration 14000 reward: 1.4328571428571428
# Iteration 15000 reward: 1.4314666666666667
# Iteration 16000 reward: 1.43425
# Iteration 17000 reward: 1.432
# Iteration 18000 reward: 1.428388888888889
# Iteration 19000 reward: 1.4293157894736843
# Iteration 20000 reward: 1.4314
# Iteration 21000 reward: 1.4304285714285714
# Iteration 22000 reward: 1.429
# Iteration 23000 reward: 1.4264782608695652
# Iteration 24000 reward: 1.42875
# Iteration 25000 reward: 1.42812
# Iteration 26000 reward: 1.4266153846153846
# ...

# %%
import matplotlib.pyplot as plt


# Plot the average rewards over iterations
plt.figure(figsize=(10, 5))
plt.plot(q_learning_agent.rewards, label='Average Reward', color='blue')
plt.title('Average Reward per Iteration')
plt.xlabel('Iterations (every step)')
plt.ylabel('Average Reward')
plt.legend()
plt.grid()
plt.show()
