# %%
from util.csv_util import *

create_csv('throughput.csv', 'η', 'Average throughput')
insert_row('throughput.csv', 0.1, 12)
insert_row('throughput.csv', 0.2, 15)
insert_row('throughput.csv', 0.3, 14)
insert_row('throughput.csv', 0.4, 11)
insert_row('throughput.csv', 0.5, 6)
insert_row('throughput.csv', 0.6, 9)
insert_row('throughput.csv', 0.7, 9)
insert_row('throughput.csv', 0.8, 15)
# Out:
# csv/throughput.csv created with 2 columns.
# /Users/dunghoangtrung125/workspace/personal/graduation_thesis/drl_sample/util/csv_util.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)

# %%
# Traning ddqn network with jam me if you can param
from dqn import DQN

ddqn = DQN(dueling=True)
ddqn.learning()
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# csv/ddqn.csv already exists.
# 2024-11-13 18:12:05.046445: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-13 18:12:05.046551: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-11-13 18:12:05.253057: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-11-13 18:12:05.296395: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('csv/ddqn.csv')

plt.figure(figsize=(10, 5))  # Set the figure size
plt.plot(df['Iteration'], df['Avg Throughput'], marker='o')  # Create a line plot
plt.tight_layout()  # Adjust layout to make room for rotated date labels

plt.show()  # Display the plot

# %%
import pandas as pd

df = pd.read_csv('csv/throughput.csv')
df.head()
# Out:
#      η  Average throughput
# 0  0.5                1343
# 1  0.5                1343
