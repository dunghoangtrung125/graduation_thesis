# %%
from conventionmethod.harvest_then_transmit import HarvestThenTransmitt

htt = HarvestThenTransmitt()
htt.simulate()
# Out:
# Average throughput at 1000 is 0.807, package lost = 2219
# Average throughput at 2000 is 0.8175, package lost = 4282
# Average throughput at 3000 is 0.8083333333333333, package lost = 6451
# Average throughput at 4000 is 0.8035, package lost = 8721
# Average throughput at 5000 is 0.8084, package lost = 10868
# Average throughput at 6000 is 0.8058333333333333, package lost = 13066
# Average throughput at 7000 is 0.8038571428571428, package lost = 15196
# Average throughput at 8000 is 0.79925, package lost = 17397
# Average throughput at 9000 is 0.7978888888888889, package lost = 19619
# Average throughput at 10000 is 0.7972, package lost = 21820
# Average throughput at 11000 is 0.7936363636363636, package lost = 24105
# Average throughput at 12000 is 0.7925833333333333, package lost = 26316
# Average throughput at 13000 is 0.7915384615384615, package lost = 28486
# Average throughput at 14000 is 0.79, package lost = 30733
# ...

# %%
from deep_q_learning_agent import DeepQLearningAgent
from deep_q_simulation.deep_q_learning_simulation import DeepQLearningSimulation

deep_q = DeepQLearningSimulation()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/tf-drl-book/lib/python3.11/site-packages/keras/saving/serialization_lib.py:541, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     540 try:
# --> 541     mod = importlib.import_module(module)
#     542 except ModuleNotFoundError:
#
# File /opt/anaconda3/envs/tf-drl-book/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# ...
